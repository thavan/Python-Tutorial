# %% [markdown]
# ## 9. Files

# %% [markdown]
# ### 9.1 Reading from a File

# %%
file_object = open('sample.txt')

# %%
file_object.read()
# Out:
# 'hello\nworld\n\nline 3\nline 4\n'

# %%
file_object.read()
# Out:
# ''

# %%
file_object.seek(0) # moves the file reading position to zero
# Out:
# 0

# %%
file_object.readline()
# Out:
# 'hello\n'

# %%
file_object.readline()
# Out:
# 'world\n'

# %%
file_object.readline()
# Out:
# '\n'

# %%
not file_object.readline()
# Out:
# False

# %%
file_object.seek(0)
# Out:
# 0

# %%
for line in file_object: # read line by line
    print(line)
# Out:
# hello
#
# world
#
#
#
# line 3
#
# line 4

# %%
file_object.close()

# %%
file_object = open('sample.txt')

# %%
file_object.readlines()
# Out:
# ['hello\n', 'world\n', '\n', 'line 3\n', 'line 4\n']

# %%
file_object.close()

# %%
with open('sample.txt') as file_object:
    for line in file_object:
        print(line)
# Out:
# hello
#
# world
#
#
#
# line 3
#
# line 4

# %% [markdown]
# ### Writing to a File

# %%
file_object = open('sample2.txt', 'w')

# %%
file_object.write('line one text')
# Out:
# 13

# %%
file_object.write('\nLine two text')
# Out:
# 14

# %%
file_object.close()

# %%
with open('sample3.txt', 'w') as f:
    for i in range(10):
        f.write(str(i) + '\n')

# %% [markdown]
# ### Appending to a File

# %%
with open('sample3.txt', 'a') as f:
    for i in range(11, 30):
        f.write(str(i) + '\n')

# %% [markdown]
# Excercise:
#
# ```Read a file and copy the contents to another file.```

# %%
with open('sample4.txt', 'w') as wf:
    with open('sample3.txt') as rf:
        wf.write(rf.read())

# %% [markdown]
# ### 12.4 Common File Operations

# %% [markdown]
# #### 12.4.1 Check if a file exists

# %%
import os
os.path.exists('/home/flower.txt')
# Out:
# False

# %%
os.path.exists('C:\\Temp')
# Out:
# True

# %% [markdown]
# #### 12.4.2 Check if a given path is file or directory

# %%
os.path.isfile('C:\\Temp')
# Out:
# False

# %% [markdown]
# #### 12.4.3 Checking if a directory exists before creating

# %%
import os
directory = "C:\\Temp\\Animals\\Cat\\"
if not os.path.exists(directory):
    os.makedirs(directory) # Recursively create a directory
